# %%
import os

from arcgis.gis import GIS
from arcgis.geoenrichment import get_countries, Country
from dotenv import find_dotenv, load_dotenv

# %%
load_dotenv(find_dotenv())

gis = GIS(
    url=os.getenv('ESRI_GIS_URL'), 
    username=os.getenv('ESRI_GIS_USERNAME'),
    password=os.getenv('ESRI_GIS_PASSWORD')
)

gis
# Out:
# GIS @ https://bateam.maps.arcgis.com version:9.2

# %%
get_countries(as_df=True, gis=GIS('pro'))
# Out:
#   iso2 iso3   country_name  vintage     country_id        data_source_id
# 0   CA  CAN         Canada     2020  CAN_ESRI_2019  LOCAL;;CAN_ESRI_2019
# 1   JP  JPN          Japan     2020      JAPAN2020      LOCAL;;JAPAN2020
# 2   US  USA  United States     2019  USA_ESRI_2019  LOCAL;;USA_ESRI_2019
# 3   US  USA  United States     2020  USA_ESRI_2020  LOCAL;;USA_ESRI_2020
# 4   US  USA  United States     2021  USA_ESRI_2021  LOCAL;;USA_ESRI_2021

# %%
cntry = Country('USA', gis=GIS('pro'), year=2019)

cntry
# Out:
# <Country - United States 2019 ('local')>

# %%
ev = cntry.enrich_variables

print(ev.info())
ev.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16911 entries, 0 to 16910
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               16911 non-null  object
#  1   alias              16911 non-null  object
#  2   data_collection    16911 non-null  object
#  3   enrich_name        16911 non-null  object
#  4   enrich_field_name  16911 non-null  object
# dtypes: object(5)
# memory usage: 660.7+ KB
# None
#          name                        alias data_collection  \
# 0    CHILD_CY        2019 Child Population   AgeDependency
# 1  WORKAGE_CY  2019 Working-age Population   AgeDependency
# 2   SENIOR_CY       2019 Senior Population   AgeDependency
# 3  CHLDDEP_CY  2019 Child Dependency Ratio   AgeDependency
# 4   AGEDEP_CY    2019 Age Dependency Ratio   AgeDependency
#
#                 enrich_name         enrich_field_name
# 0    AgeDependency.CHILD_CY    AgeDependency_CHILD_CY
# ...

# %%
kv = ev[
    (ev.data_collection.str.lower().str.contains('key'))
    & (ev.name.str.endswith('CY'))
].drop_duplicates('name').reset_index(drop=True)

kv
# Out:
#           name                              alias data_collection  \
# 0    TOTPOP_CY              2019 Total Population      KeyUSFacts
# 1     GQPOP_CY  2019 Population in Group Quarters      KeyUSFacts
# 2   DIVINDX_CY               2019 Diversity Index      KeyUSFacts
# 3     TOTHH_CY              2019 Total Households      KeyUSFacts
# 4   AVGHHSZ_CY        2019 Average Household Size      KeyUSFacts
# 5   MEDHINC_CY       2019 Median Household Income      KeyUSFacts
# 6   AVGHINC_CY      2019 Average Household Income      KeyUSFacts
# 7       PCI_CY             2019 Per Capita Income      KeyUSFacts
# 8     TOTHU_CY           2019 Total Housing Units      KeyUSFacts
# 9     OWNER_CY            2019 Owner Occupied HUs      KeyUSFacts
# 10   RENTER_CY           2019 Renter Occupied HUs      KeyUSFacts
# 11   VACANT_CY          2019 Vacant Housing Units      KeyUSFacts
# 12   MEDVAL_CY             2019 Median Home Value      KeyUSFacts
# ...
