# %% [markdown]
# ## Imports and Setup

# %%
import importlib
import os
from pathlib import Path
import sys

from arcgis.features import GeoAccessor, FeatureLayer
from arcgis.geoenrichment import get_countries, Country, enrich  # geoenrichment imports
from arcgis.geometry.filters import contains
from arcgis.gis import GIS
import arcpy
from dotenv import load_dotenv, find_dotenv
import pandas as pd

# %%
# paths to common data locations - NOTE: to convert any path to a raw string, simply use str(path_instance)
dir_prj = Path.cwd().parent
dir_data = dir_prj/'data'
dir_raw = dir_data/'raw'
dir_int = dir_data/'interim'

# load environment variables from .env
load_dotenv(find_dotenv())

# create a GIS object instance connecting to Pro
gis = GIS('Pro')

# ensure multiple runs do not cause problems
arcpy.env.overwriteOutput = True

# %%
template_df = pd.read_csv(dir_raw/'previously_enriched.csv', index_col=0)

template_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   geoid                  5 non-null      int64
#  1   HasData                5 non-null      int64
#  2   aggregationMethod      5 non-null      object
#  3   KeyUSFacts_TOTPOP_CY   5 non-null      float64
#  4   KeyUSFacts_GQPOP_CY    5 non-null      float64
#  5   KeyUSFacts_DIVINDX_CY  5 non-null      float64
#  6   KeyUSFacts_TOTHH_CY    5 non-null      float64
#  7   KeyUSFacts_AVGHHSZ_CY  5 non-null      float64
#  8   KeyUSFacts_MEDHINC_CY  5 non-null      float64
#  9   KeyUSFacts_AVGHINC_CY  5 non-null      float64
#  10  KeyUSFacts_PCI_CY      5 non-null      float64
#  11  KeyUSFacts_TOTHU_CY    5 non-null      float64
#  12  KeyUSFacts_OWNER_CY    5 non-null      float64
#  13  KeyUSFacts_RENTER_CY   5 non-null      float64
#  14  KeyUSFacts_VACANT_CY   5 non-null      float64
#  15  KeyUSFacts_MEDVAL_CY   5 non-null      float64
#  16  KeyUSFacts_AVGVAL_CY   5 non-null      float64
#  17  KeyUSFacts_POPGRW10CY  5 non-null      float64
#  18  KeyUSFacts_HHGRW10CY   5 non-null      float64
#  19  KeyUSFacts_FAMGRW10CY  5 non-null      float64
#  20  KeyUSFacts_DPOP_CY     5 non-null      float64
#  21  KeyUSFacts_DPOPWRK_CY  5 non-null      float64
#  22  KeyUSFacts_DPOPRES_CY  5 non-null      float64
#  23  sports_MP33002a_B      5 non-null      float64
#  24  sports_MP33005a_B      5 non-null      float64
#  25  sports_MP33006a_B      5 non-null      float64
#  26  sports_MP33009a_B      5 non-null      float64
#  27  sports_MP33015a_B      5 non-null      float64
#  28  sports_MP33020a_B      5 non-null      float64
#  29  sports_MP33023a_B      5 non-null      float64
#  30  sports_MP33030a_B      5 non-null      float64
#  31  sports_MP33033a_B      5 non-null      float64
#  32  sports_MP33034a_B      5 non-null      float64
#  33  sports_MP33035a_B      5 non-null      float64
#  34  sports_MP33050a_B      5 non-null      float64
#  35  SHAPE                  5 non-null      object
# dtypes: float64(32), int64(2), object(2)
# memory usage: 1.4+ KB

# %%
usa = Country('USA', gis=gis)

usa
# Out:
# <Country - United States 2021 ('local')>

# %%
ev = usa.enrich_variables

ev
# Out:
#              name                                              alias  \
# 0        CHILD_CY                              2021 Child Population
# 1      WORKAGE_CY                        2021 Working-Age Population
# 2       SENIOR_CY                             2021 Senior Population
# 3      CHLDDEP_CY                        2021 Child Dependency Ratio
# 4       AGEDEP_CY                          2021 Age Dependency Ratio
# ...           ...                                                ...
# 17958  MOEMEDYRMV  2019 Median Year Householder Moved In MOE (ACS...
# 17959  RELMEDYRMV  2019 Median Year Householder Moved In REL (ACS...
# 17960    ACSOWNER                   2019 Owner Households (ACS 5-Yr)
# 17961    MOEOWNER               2019 Owner Households MOE (ACS 5-Yr)
# 17962    RELOWNER               2019 Owner Households REL (ACS 5-Yr)
#
#       data_collection               enrich_name         enrich_field_name
# 0       AgeDependency    AgeDependency.CHILD_CY    AgeDependency_CHILD_CY
# 1       AgeDependency  AgeDependency.WORKAGE_CY  AgeDependency_WORKAGE_CY
# 2       AgeDependency   AgeDependency.SENIOR_CY   AgeDependency_SENIOR_CY
# 3       AgeDependency  AgeDependency.CHLDDEP_CY  AgeDependency_CHLDDEP_CY
# 4       AgeDependency   AgeDependency.AGEDEP_CY   AgeDependency_AGEDEP_CY
# ...               ...                       ...                       ...
# 17958     yearmovedin    yearmovedin.MOEMEDYRMV    yearmovedin_MOEMEDYRMV
# 17959     yearmovedin    yearmovedin.RELMEDYRMV    yearmovedin_RELMEDYRMV
# 17960     yearmovedin      yearmovedin.ACSOWNER      yearmovedin_ACSOWNER
# 17961     yearmovedin      yearmovedin.MOEOWNER      yearmovedin_MOEOWNER
# 17962     yearmovedin      yearmovedin.RELOWNER      yearmovedin_RELOWNER
#
# [17963 rows x 5 columns]

# %%
sv = ev[
    (
        (ev.data_collection.str.lower().str.contains('key'))
        & (ev.name.str.endswith('CY'))
    )
    | (
        (ev.data_collection == 'sports')
        & (
            ev.alias.str.lower().str.contains('backpacking')
            | ev.alias.str.lower().str.contains('bicycling')
            | ev.alias.str.lower().str.contains('canoeing')
            | ev.alias.str.lower().str.contains('hiking')
            | ev.alias.str.lower().str.contains('running')
            | ev.alias.str.lower().str.contains('skiing') 
            | ev.alias.str.lower().str.contains('walking') 
            | ev.alias.str.lower().str.contains('spent')
        )
    )
].drop_duplicates().reset_index(drop=True)

# %%
sv = ev[ev.enrich_field_name.isin(template_df.columns)].reset_index(drop=True)

sv
# Out:
#           name                                              alias  \
# 0    TOTPOP_CY                              2021 Total Population
# 1     GQPOP_CY                     2021 Group Quarters Population
# 2   DIVINDX_CY                               2021 Diversity Index
# 3     TOTHH_CY                              2021 Total Households
# 4   AVGHHSZ_CY                        2021 Average Household Size
# 5   MEDHINC_CY                       2021 Median Household Income
# 6   AVGHINC_CY                      2021 Average Household Income
# 7       PCI_CY                             2021 Per Capita Income
# 8     TOTHU_CY                           2021 Total Housing Units
# 9     OWNER_CY                            2021 Owner Occupied HUs
# 10   RENTER_CY                           2021 Renter Occupied HUs
# 11   VACANT_CY                          2021 Vacant Housing Units
# 12   MEDVAL_CY                             2021 Median Home Value
# 13   AVGVAL_CY                            2021 Average Home Value
# 14  POPGRW10CY                  2010-2021 Growth Rate: Population
# 15   HHGRW10CY                  2010-2021 Growth Rate: Households
# 16  FAMGRW10CY                    2010-2021 Growth Rate: Families
# 17     DPOP_CY                      2021 Total Daytime Population
# 18  DPOPWRK_CY                          2021 Daytime Pop: Workers
# 19  DPOPRES_CY                        2021 Daytime Pop: Residents
# 20  MP33002a_B             2021 Participated in Backpacking/12 Mo
# 21  MP33005a_B    2021 Participated in Bicycling (Mountain)/12 Mo
# 22  MP33006a_B        2021 Participated in Bicycling (Road)/12 Mo
# 23  MP33009a_B    2021 Participated in Canoeing or Kayaking/12 Mo
# 24  MP33015a_B                  2021 Participated in Hiking/12 Mo
# 25  MP33020a_B      2021 Participated in Jogging or Running/12 Mo
# 26  MP33023a_B        2021 Participated in Skiing(Downhill)/12 Mo
# 27  MP33030a_B    2021 Participated in Walking For Exercise/12 Mo
# 28  MP33033a_B  2021 Spent $1-99 On Sports/Recreation Equip/12 Mo
# 29  MP33034a_B  2021 Spent $100-249 On Sports/Recreation Equip...
# 30  MP33035a_B  2021 Spent $250+ On Sports/Recreation Equip/12 Mo
# 31  MP33050a_B      2021 Watch Alpine Skiing or Ski Jumping On TV
#
#    data_collection            enrich_name      enrich_field_name
# 0       KeyUSFacts   KeyUSFacts.TOTPOP_CY   KeyUSFacts_TOTPOP_CY
# 1       KeyUSFacts    KeyUSFacts.GQPOP_CY    KeyUSFacts_GQPOP_CY
# 2       KeyUSFacts  KeyUSFacts.DIVINDX_CY  KeyUSFacts_DIVINDX_CY
# 3       KeyUSFacts    KeyUSFacts.TOTHH_CY    KeyUSFacts_TOTHH_CY
# 4       KeyUSFacts  KeyUSFacts.AVGHHSZ_CY  KeyUSFacts_AVGHHSZ_CY
# 5       KeyUSFacts  KeyUSFacts.MEDHINC_CY  KeyUSFacts_MEDHINC_CY
# 6       KeyUSFacts  KeyUSFacts.AVGHINC_CY  KeyUSFacts_AVGHINC_CY
# 7       KeyUSFacts      KeyUSFacts.PCI_CY      KeyUSFacts_PCI_CY
# 8       KeyUSFacts    KeyUSFacts.TOTHU_CY    KeyUSFacts_TOTHU_CY
# 9       KeyUSFacts    KeyUSFacts.OWNER_CY    KeyUSFacts_OWNER_CY
# 10      KeyUSFacts   KeyUSFacts.RENTER_CY   KeyUSFacts_RENTER_CY
# 11      KeyUSFacts   KeyUSFacts.VACANT_CY   KeyUSFacts_VACANT_CY
# 12      KeyUSFacts   KeyUSFacts.MEDVAL_CY   KeyUSFacts_MEDVAL_CY
# 13      KeyUSFacts   KeyUSFacts.AVGVAL_CY   KeyUSFacts_AVGVAL_CY
# 14      KeyUSFacts  KeyUSFacts.POPGRW10CY  KeyUSFacts_POPGRW10CY
# 15      KeyUSFacts   KeyUSFacts.HHGRW10CY   KeyUSFacts_HHGRW10CY
# 16      KeyUSFacts  KeyUSFacts.FAMGRW10CY  KeyUSFacts_FAMGRW10CY
# 17      KeyUSFacts     KeyUSFacts.DPOP_CY     KeyUSFacts_DPOP_CY
# 18      KeyUSFacts  KeyUSFacts.DPOPWRK_CY  KeyUSFacts_DPOPWRK_CY
# 19      KeyUSFacts  KeyUSFacts.DPOPRES_CY  KeyUSFacts_DPOPRES_CY
# 20          sports      sports.MP33002a_B      sports_MP33002a_B
# 21          sports      sports.MP33005a_B      sports_MP33005a_B
# 22          sports      sports.MP33006a_B      sports_MP33006a_B
# 23          sports      sports.MP33009a_B      sports_MP33009a_B
# 24          sports      sports.MP33015a_B      sports_MP33015a_B
# 25          sports      sports.MP33020a_B      sports_MP33020a_B
# 26          sports      sports.MP33023a_B      sports_MP33023a_B
# 27          sports      sports.MP33030a_B      sports_MP33030a_B
# 28          sports      sports.MP33033a_B      sports_MP33033a_B
# 29          sports      sports.MP33034a_B      sports_MP33034a_B
# 30          sports      sports.MP33035a_B      sports_MP33035a_B
# 31          sports      sports.MP33050a_B      sports_MP33050a_B

# %%
# create a layer to access named places through an anonymous connection to ArcGIS Online
places_id = '13ea1fb24ca14842bb265e6ec6ac1d46'
places_lyr = GIS().content.get(places_id).layers[0]

# retrieve named place (city)
sql_str = "NAME LIKE '%Portland%' AND State_Name = 'Oregon'"
pdx_df = places_lyr.query(sql_str, out_fields=['GEOID', 'NAME', 'State_Name'], out_sr=4326).sdf

pdx_df
# Out:
#    OBJECTID    GEOID           NAME State_Name  \
# 0      3298  4159000  Portland city     Oregon
#
#                                                SHAPE
# 0  {"rings": [[[-122.564776452646, 45.46045947276...

# %%
# create a filter object to use with the query
pdx_fltr = contains(pdx_df.iloc[0][pdx_df.spatial.name], sr=4326)

# create a feature layer connecting to the census server block group layer
bg_id = 'd1105f1e65a743cc84fc12c034625fc7'
bg_lyr = gis.content.get(bg_id).layers[0]

# use the filter created above to retrieve the block groups contained in the named place
bg_df = bg_lyr.query(geometry_filter=pdx_fltr, out_fields=['GEOID'], out_sr=4326).sdf

print(bg_df.info())
bg_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OBJECTID  447 non-null    int64
#  1   GEOID     447 non-null    object
#  2   SHAPE     447 non-null    geometry
# dtypes: geometry(1), int64(1), object(1)
# memory usage: 10.6+ KB
# None
#    OBJECTID         GEOID                                              SHAPE
# 0     72951  410510064033  {"rings": [[[-122.731105475247, 45.44711945483...
# 1     72953  410510065011  {"rings": [[[-122.734135478327, 45.46041145564...
# 2     73026  410510001023  {"rings": [[[-122.653010466564, 45.46504146431...
# 3     73027  410510001024  {"rings": [[[-122.666498469333, 45.46493846278...
# 4     73028  410510062002  {"rings": [[[-122.697364473799, 45.46453145975...

# %%
# convert this to a feature class in RAM so it can be used with ArcGIS Pro GeoProcessing tools
bg_fc = bg_df.spatial.to_featureclass('memory/bg_tmp')

# run enrich layer geoprocessing tool
enrich_fc = arcpy.ba.EnrichLayer(
    in_features=bg_fc,                     # use temporary feature class as input
    out_feature_class=f'memory/enrch_tmp', # store in memory so can manipulate
    variables=list(sv.enrich_name)         # create list from series
)[0]                                       # first item from result object

# convert results to a dataframe
enrich_df = GeoAccessor.from_featureclass(enrich_fc)

print(enrich_df.info())
enrich_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OBJECTID               447 non-null    int64
#  1   geoid                  447 non-null    object
#  2   HasData                447 non-null    int64
#  3   aggregationMethod      447 non-null    object
#  4   KeyUSFacts_TOTPOP_CY   447 non-null    float64
#  5   KeyUSFacts_GQPOP_CY    447 non-null    float64
#  6   KeyUSFacts_DIVINDX_CY  447 non-null    float64
#  7   KeyUSFacts_TOTHH_CY    447 non-null    float64
#  8   KeyUSFacts_AVGHHSZ_CY  447 non-null    float64
#  9   KeyUSFacts_MEDHINC_CY  447 non-null    float64
#  10  KeyUSFacts_AVGHINC_CY  447 non-null    float64
#  11  KeyUSFacts_PCI_CY      447 non-null    float64
#  12  KeyUSFacts_TOTHU_CY    447 non-null    float64
#  13  KeyUSFacts_OWNER_CY    447 non-null    float64
#  14  KeyUSFacts_RENTER_CY   447 non-null    float64
#  15  KeyUSFacts_VACANT_CY   447 non-null    float64
#  16  KeyUSFacts_MEDVAL_CY   447 non-null    float64
#  17  KeyUSFacts_AVGVAL_CY   447 non-null    float64
#  18  KeyUSFacts_POPGRW10CY  447 non-null    float64
#  19  KeyUSFacts_HHGRW10CY   447 non-null    float64
#  20  KeyUSFacts_FAMGRW10CY  447 non-null    float64
#  21  KeyUSFacts_DPOP_CY     447 non-null    float64
#  22  KeyUSFacts_DPOPWRK_CY  447 non-null    float64
#  23  KeyUSFacts_DPOPRES_CY  447 non-null    float64
#  24  sports_MP33002a_B      447 non-null    float64
#  25  sports_MP33005a_B      447 non-null    float64
#  26  sports_MP33006a_B      447 non-null    float64
#  27  sports_MP33009a_B      447 non-null    float64
#  28  sports_MP33015a_B      447 non-null    float64
#  29  sports_MP33020a_B      447 non-null    float64
#  30  sports_MP33023a_B      447 non-null    float64
#  31  sports_MP33030a_B      447 non-null    float64
#  32  sports_MP33033a_B      447 non-null    float64
#  33  sports_MP33034a_B      447 non-null    float64
#  34  sports_MP33035a_B      447 non-null    float64
#  35  sports_MP33050a_B      447 non-null    float64
#  36  SHAPE                  447 non-null    geometry
# dtypes: float64(32), geometry(1), int64(2), object(2)
# memory usage: 129.3+ KB
# None
#    OBJECTID         geoid  HasData                  aggregationMethod  \
# 0         1  410510064033        1  BlockApportionment:US.BlockGroups
# 1         2  410510065011        1  BlockApportionment:US.BlockGroups
# 2         3  410510001023        1  BlockApportionment:US.BlockGroups
# 3         4  410510001024        1  BlockApportionment:US.BlockGroups
# 4         5  410510062002        1  BlockApportionment:US.BlockGroups
#
#    KeyUSFacts_TOTPOP_CY  KeyUSFacts_GQPOP_CY  KeyUSFacts_DIVINDX_CY  \
# 0                1235.0                  0.0                   66.2
# 1                1997.0                  0.0                   33.7
# 2                 806.0                  0.0                   35.5
# 3                1086.0                  0.0                   29.0
# 4                 901.0                  0.0                   28.1
#
#    KeyUSFacts_TOTHH_CY  KeyUSFacts_AVGHHSZ_CY  KeyUSFacts_MEDHINC_CY  ...  \
# 0                505.0                   2.45                61338.0  ...
# 1                860.0                   2.32               128390.0  ...
# 2                338.0                   2.38               106192.0  ...
# 3                473.0                   2.30                94737.0  ...
# 4                395.0                   2.28               119302.0  ...
#
#    sports_MP33009a_B  sports_MP33015a_B  sports_MP33020a_B  sports_MP33023a_B  \
# 0               66.0              119.0              142.0               19.0
# 1              146.0              352.0              252.0               87.0
# 2               83.0              111.0              112.0               29.0
# 3              116.0              155.0              157.0               40.0
# 4               66.0              100.0               94.0               27.0
#
#    sports_MP33030a_B  sports_MP33033a_B  sports_MP33034a_B  sports_MP33035a_B  \
# 0              213.0               76.0               23.0               44.0
# 1              490.0              111.0               90.0              101.0
# 2              176.0               55.0               47.0               49.0
# 3              246.0               77.0               65.0               69.0
# 4              231.0               40.0               54.0               61.0
#
#    sports_MP33050a_B                                              SHAPE
# 0               15.0  {"rings": [[[-122.73110547499999, 45.447119455...
# 1               95.0  {"rings": [[[-122.73413547799998, 45.460411456...
# 2               30.0  {"rings": [[[-122.65301046699994, 45.465041464...
# 3               42.0  {"rings": [[[-122.66649846899998, 45.464938463...
# 4               33.0  {"rings": [[[-122.69736447399998, 45.464531460...
#
# [5 rows x 37 columns]
