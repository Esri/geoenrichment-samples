# %%
import json
import os
from pathlib import Path

from arcgis.gis import GIS
from dotenv import find_dotenv, load_dotenv
import pandas as pd
import requests

# %%
load_dotenv(find_dotenv())

dir_prj = Path.cwd().parent
dir_data = dir_prj/'data'
dir_reports = dir_prj/'reports'
assert dir_reports.exists()

url, user, pswd = [os.getenv(itm) for itm in ['AGOL_URL', 'AGOL_USERNAME', 'AGOL_PASSWORD']]
assert all([url, user, pswd])

gis = GIS(url, username=user, password=pswd)

gis
# Out:
# GIS @ https://baqa.mapsqa.arcgis.com version:9.3

# %%
reports_url = gis.properties.helperServices.geoenrichment.url + "/Geoenrichment/Reports"

reports_url
# Out:
# 'https://geoenrichqa.arcgis.com/arcgis/rest/services/World/GeoenrichmentServer/Geoenrichment/Reports'

# %%
infographic_url = gis.properties.helperServices.geoenrichment.url + '/Geoenrichment/Infographics/Standard/US/census'

infographic_url
# Out:
# 'https://geoenrichqa.arcgis.com/arcgis/rest/services/World/GeoenrichmentServer/Geoenrichment/Infographics/Standard/US/census'

# %%
payload = {
    'f': 'json'
}
res = requests.get(infographic_url, params=payload)

res
# Out:
# <Response [200]>

# %%
res = gis._con.post(infographic_url, params={'f': 'json'}, ignore_error_key=False)

# 
std_ig_df = pd.json_normalize(res['reports'])
std_ig_df.columns = [col.replace('metadata.', '') for col in std_ig_df.columns]
std_ig_df = std_ig_df[['reportID', 'title', 'itemID', 'formats', 'dataVintage', 'dataVintageDescription', 'countries', 'hierarchy']].copy()
std_ig_df['category'] = 'standard'

std_ig_df
# Out:
#                        reportID                                 title  \
# 0            at-risk-population                    At Risk Population
# 1               commute-profile                       Commute Profile
# 2   coronavirus-impact-planning           Coronavirus Impact Planning
# 3           demographic-profile                   Demographic Profile
# 4           demographic-summary                   Demographic Summary
# 5     dominant-tapestry-profile             Dominant Tapestry Profile
# 6           employment-overview                   Employment Overview
# 7   executive-summary-call-outs         Executive Summary - Call Outs
# 8     health-care-and-insurance  Health Care and Insurance Statistics
# 9                     key-facts                             Key Facts
# 10        multi-area-comparison                 Multi-area Comparison
# 11           nearby-restaurants                    Nearby Restaurants
# 12        office-market-profile                 Office Market Profile
# 13            population-trends                     Population Trends
# 14             property-details                      Property Details
# 15                   skyscraper                            Skyscraper
# 16             tapestry-profile                      Tapestry Profile
# 17        target-market-summary                 Target Market Summary
#
#                               itemID      formats            dataVintage  \
# 0   12ba522ef56047b8a8f29db28002d1ef  [pdf, html]  2015-2019, 2021, 2026
# 1   26b07d8e0c3d415bbb0aa9a48d78ca99  [pdf, html]              2015-2019
# 2   0bd7edb522a2442bb3c3b12217070192  [pdf, html]  2015-2019, 2021, 2026
# 3   7666fe3ce3424648971f8492ee94bb17  [pdf, html]             2021, 2026
# 4   2ce64a16cb3c431186a47c6a42156515  [pdf, html]             2021, 2026
# 5   ba3c7377d43149d5b4a8afc93faaa606  [pdf, html]  2015-2019, 2021, 2026
# 6   84e39eb8e4b94e3792658edce55154a4  [pdf, html]  2015-2019, 2021, 2026
# 7   3897af12da5c4e60bf6acdfd0f61f45d  [pdf, html]             2021, 2026
# 8   91f0ffdaca2f4854921dd812713441c3  [pdf, html]        2015-2019, 2021
# 9   9182d4b3cf9b4e22a3f577b93b43031f  [pdf, html]             2021, 2026
# 10  472eb2651f454261baa991dd56a199c5  [pdf, html]                   2021
# 11  2665a41232c94c8e84a59979eb9c97fd  [pdf, html]             2021, 2026
# 12  0d92f85fbf054541ab0e32d814f89a8d  [pdf, html]             2021, 2026
# 13  53d532fd2837446f947f2e54b9f8d19e  [pdf, html]  2015-2019, 2021, 2026
# 14  4e1344a2ec15444d8563209610091063  [pdf, html]             2021, 2026
# 15  80ad6dcd9f8c4790b87393c6b23c0116  [pdf, html]             2021, 2026
# 16  62964574ebb7418b92f08789ed438441  [pdf, html]                   2021
# 17  e62c646c006e45668f43f51bf1f7cfaf  [pdf, html]             2021, 2026
#
#                                dataVintageDescription countries hierarchy  \
# 0   This infographic contains data provided by Ame...        US    census
# 1   This infographic contains data provided by Ame...        US    census
# 2   This infographic contains data provided by Ame...        US    census
# 3   This infographic contains data provided by Esr...        US    census
# 4   This infographic contains data provided by Esr...        US    census
# 5   This infographic contains data provided by Ame...        US    census
# 6   This infographic contains data provided by Ame...        US    census
# 7   This infographic contains data provided by Esr...        US    census
# 8   This infographic contains data provided by Ame...        US    census
# 9   This infographic contains data provided by Esr...        US    census
# 10  This infographic contains data provided by Esr...        US    census
# 11  This infographic contains data provided by Esr...        US    census
# 12  This infographic contains data provided by Esr...        US    census
# 13  This infographic contains data provided by Ame...        US    census
# 14  This infographic contains data provided by Esr...        US    census
# 15  This infographic contains data provided by Esr...        US    census
# 16  This infographic contains data provided by Esr...        US    census
# 17  This infographic contains data provided by Esr...        US    census
#
#     category
# 0   standard
# 1   standard
# 2   standard
# 3   standard
# 4   standard
# 5   standard
# 6   standard
# 7   standard
# 8   standard
# 9   standard
# 10  standard
# 11  standard
# 12  standard
# 13  standard
# 14  standard
# 15  standard
# 16  standard
# 17  standard

# %%
gis.content.search('Public Safety Test')
# Out:
# [<Item title:"Public Safety Test" type:Report Template owner:jmccune_baqa>]

# %%
gis.content.search('owner:jmccune_baqa')
# Out:
# [<Item title:"Test Oly" type:Web Map owner:jmccune_baqa>,
#  <Item title:"Default Feature Service Preferences" type:Web Mapping Application owner:jmccune_baqa>,
#  <Item title:"BA Project Map Data" type:Web Mapping Application owner:jmccune_baqa>,
#  <Item title:"BA Web App Comparison Reports Variables" type:Web Mapping Application owner:jmccune_baqa>,
#  <Item title:"BA Web App Guided Tour Data" type:Web Mapping Application owner:jmccune_baqa>,
#  <Item title:"BA Project Preferences" type:Web Mapping Application owner:jmccune_baqa>,
#  <Item title:"Test Sites" type:Web Mapping Application owner:jmccune_baqa>,
#  <Item title:"BA Web App Smart Map Search Data" type:Web Mapping Application owner:jmccune_baqa>,
#  <Item title:"BA Web App Custom Color Ramps" type:Web Mapping Application owner:jmccune_baqa>,
#  <Item title:"BA Web App Comparison Reports Data" type:Web Mapping Application owner:jmccune_baqa>]

# %%
itm_lst = gis.content.search('type:Report Template')

itm_lst
# Out:
# [<Item title:"Text & Dates" type:Report Template owner:cconnollyqa>,
#  <Item title:"Custom Info Xavier" type:Report Template owner:mrothman_baqa>,
#  <Item title:"trst6 2" type:Report Template owner:Psrivastava_baqa>,
#  <Item title:"Custom Comparison" type:Report Template owner:dstauningqa>,
#  <Item title:"Meijer Infographic 1" type:Report Template owner:dyuan_baqa>,
#  <Item title:"Infographic_Test_Alex" type:Report Template owner:mrothman_baqa>,
#  <Item title:"test nearby1" type:Report Template owner:Psrivastava_baqa>,
#  <Item title:"test2" type:Report Template owner:Psrivastava_baqa>,
#  <Item title:"Multi-ring Comparison (Esri infographic) US" type:Report Template owner:chris_baqa>,
#  <Item title:"Key Facts (Esri infographic) CA" type:Report Template owner:dstauningqa>]

# %%
ig_itm_lst = [itm for itm in itm_lst if any([kw for kw in itm.typeKeywords if 'infographic' in kw.lower()])]

ig_dict_lst = []
for itm in ig_itm_lst:
    itm_dict = {
        'title': itm.__dict__['title'], 
        'itemID': itm.__dict__['itemid'], 
        'itemDescription': itm.__dict__['description'],
        'countries': itm.__dict__['properties']['countries'],
        'formats': itm.properties['formats'],
        'dataVintage': itm.properties['dataVintage'], 
        'dataVintageDescription': itm.properties['dataVintageDescription']
    }
    ig_dict_lst.append(itm_dict)
    
cst_ig_df = pd.DataFrame(ig_dict_lst)

cst_ig_df['category'] = 'custom'

cst_ig_df
# Out:
#                                          title  \
# 0                           Custom Info Xavier
# 1                         Meijer Infographic 1
# 2                        Infographic_Test_Alex
# 3                                 test nearby1
# 4  Multi-ring Comparison (Esri infographic) US
# 5              Key Facts (Esri infographic) CA
#
#                              itemID  \
# 0  435f91eb8fb94a4797f0d5cc669a1e97
# 1  618f004788e84a8a867b837796071bd5
# 2  5489adb5d8634b7cb27a6d709d7f8923
# 3  af6e6b21b9624bb786c6c2ad40263c40
# 4  a5a465ec4cf24c3097f3b17045a50e0f
# 5  f6d1930b68734301b5a948a96ce39a31
#
#                                      itemDescription countries formats  \
# 0  Business Analyst Report Template This infograp...        CA     pdf
# 1  Business Analyst Report Template. This infogra...        US     pdf
# 2  Business Analyst Report Template This infograp...        CA     pdf
# 3  Business Analyst Report Template This infograp...        US     pdf
# 4  Business Analyst Report Template This infograp...        US     pdf
# 5  Business Analyst Report Template. This infogra...        CA     pdf
#
#              dataVintage                             dataVintageDescription  \
# 0                   2018  This infographic contains data provided by Env...
# 1  2013-2017, 2019, 2024  This infographic contains data provided by Ame...
# 2                   2018  This infographic contains data provided by Env...
# 3             2016, 2018  This infographic contains data provided by Esr...
# 4                   2018  This infographic contains data provided by Esr...
# 5                   2018  This infographic contains data provided by Env...
#
#   category
# 0   custom
# 1   custom
# 2   custom
# 3   custom
# 4   custom
# 5   custom

# %%
uniq_cntry = std_ig_df['countries'].explode().unique()

uniq_ig_df = cst_ig_df[cst_ig_df.countries.isin(uniq_cntry)]

# %%
cst_cntry_lst = cst_ig_df[cst_ig_df.countries.isin(uniq_cntry)]

pd.concat([std_ig_df, uniq_ig_df], ignore_index=True)
# Out:
#                        reportID                                        title  \
# 0            at-risk-population                           At Risk Population
# 1               commute-profile                              Commute Profile
# 2   coronavirus-impact-planning                  Coronavirus Impact Planning
# 3           demographic-profile                          Demographic Profile
# 4           demographic-summary                          Demographic Summary
# 5     dominant-tapestry-profile                    Dominant Tapestry Profile
# 6           employment-overview                          Employment Overview
# 7   executive-summary-call-outs                Executive Summary - Call Outs
# 8     health-care-and-insurance         Health Care and Insurance Statistics
# 9                     key-facts                                    Key Facts
# 10        multi-area-comparison                        Multi-area Comparison
# 11           nearby-restaurants                           Nearby Restaurants
# 12        office-market-profile                        Office Market Profile
# 13            population-trends                            Population Trends
# 14             property-details                             Property Details
# 15                   skyscraper                                   Skyscraper
# 16             tapestry-profile                             Tapestry Profile
# 17        target-market-summary                        Target Market Summary
# 18                          NaN                         Meijer Infographic 1
# 19                          NaN                                 test nearby1
# 20                          NaN  Multi-ring Comparison (Esri infographic) US
#
#                               itemID      formats            dataVintage  \
# 0   12ba522ef56047b8a8f29db28002d1ef  [pdf, html]  2015-2019, 2021, 2026
# 1   26b07d8e0c3d415bbb0aa9a48d78ca99  [pdf, html]              2015-2019
# 2   0bd7edb522a2442bb3c3b12217070192  [pdf, html]  2015-2019, 2021, 2026
# 3   7666fe3ce3424648971f8492ee94bb17  [pdf, html]             2021, 2026
# 4   2ce64a16cb3c431186a47c6a42156515  [pdf, html]             2021, 2026
# 5   ba3c7377d43149d5b4a8afc93faaa606  [pdf, html]  2015-2019, 2021, 2026
# 6   84e39eb8e4b94e3792658edce55154a4  [pdf, html]  2015-2019, 2021, 2026
# 7   3897af12da5c4e60bf6acdfd0f61f45d  [pdf, html]             2021, 2026
# 8   91f0ffdaca2f4854921dd812713441c3  [pdf, html]        2015-2019, 2021
# 9   9182d4b3cf9b4e22a3f577b93b43031f  [pdf, html]             2021, 2026
# 10  472eb2651f454261baa991dd56a199c5  [pdf, html]                   2021
# 11  2665a41232c94c8e84a59979eb9c97fd  [pdf, html]             2021, 2026
# 12  0d92f85fbf054541ab0e32d814f89a8d  [pdf, html]             2021, 2026
# 13  53d532fd2837446f947f2e54b9f8d19e  [pdf, html]  2015-2019, 2021, 2026
# 14  4e1344a2ec15444d8563209610091063  [pdf, html]             2021, 2026
# 15  80ad6dcd9f8c4790b87393c6b23c0116  [pdf, html]             2021, 2026
# 16  62964574ebb7418b92f08789ed438441  [pdf, html]                   2021
# 17  e62c646c006e45668f43f51bf1f7cfaf  [pdf, html]             2021, 2026
# 18  618f004788e84a8a867b837796071bd5          pdf  2013-2017, 2019, 2024
# 19  af6e6b21b9624bb786c6c2ad40263c40          pdf             2016, 2018
# 20  a5a465ec4cf24c3097f3b17045a50e0f          pdf                   2018
#
#                                dataVintageDescription countries hierarchy  \
# 0   This infographic contains data provided by Ame...        US    census
# 1   This infographic contains data provided by Ame...        US    census
# 2   This infographic contains data provided by Ame...        US    census
# 3   This infographic contains data provided by Esr...        US    census
# 4   This infographic contains data provided by Esr...        US    census
# 5   This infographic contains data provided by Ame...        US    census
# 6   This infographic contains data provided by Ame...        US    census
# 7   This infographic contains data provided by Esr...        US    census
# 8   This infographic contains data provided by Ame...        US    census
# 9   This infographic contains data provided by Esr...        US    census
# 10  This infographic contains data provided by Esr...        US    census
# 11  This infographic contains data provided by Esr...        US    census
# 12  This infographic contains data provided by Esr...        US    census
# 13  This infographic contains data provided by Ame...        US    census
# 14  This infographic contains data provided by Esr...        US    census
# 15  This infographic contains data provided by Esr...        US    census
# 16  This infographic contains data provided by Esr...        US    census
# 17  This infographic contains data provided by Esr...        US    census
# 18  This infographic contains data provided by Ame...        US       NaN
# 19  This infographic contains data provided by Esr...        US       NaN
# 20  This infographic contains data provided by Esr...        US       NaN
#
#     category                                    itemDescription
# 0   standard                                                NaN
# 1   standard                                                NaN
# 2   standard                                                NaN
# 3   standard                                                NaN
# 4   standard                                                NaN
# 5   standard                                                NaN
# 6   standard                                                NaN
# 7   standard                                                NaN
# 8   standard                                                NaN
# 9   standard                                                NaN
# 10  standard                                                NaN
# 11  standard                                                NaN
# 12  standard                                                NaN
# 13  standard                                                NaN
# 14  standard                                                NaN
# 15  standard                                                NaN
# 16  standard                                                NaN
# 17  standard                                                NaN
# 18    custom  Business Analyst Report Template. This infogra...
# 19    custom  Business Analyst Report Template This infograp...
# 20    custom  Business Analyst Report Template This infograp...

# %%
from pathlib import Path
from typing import Union, List

from arcgis.geoenrichment import create_report
from arcgis.geometry import Geometry
from arcgis.gis import GIS

def custom_create_report(
    study_areas: Union[Geometry, List[Geometry]], 
    gis:GIS, report:str, 
    out_path: Union[str, Path],                      
    export_format: str = 'pdf'
):

    # ensure list
    in_geom = [study_areas] if not isinstance(study_areas, list) else study_areas

    # format geometries as list of dicts so create_report doesn't touch
    in_geom = [{'geometry': json.loads(geom.JSON)} for geom in in_geom]
    
    # validataion on export format
    export_format = export_format.lower()
    assert export_format in ['xlsx', 'pdf', 'html']
    
    # get the directory and file name
    out_folder = str(out_path.parent)
    out_name = str(out_path.name)

    # get the report
    out_report = create_report(
        study_areas=in_geom,
        report=report,
        export_format=export_format,
        out_folder=out_folder, 
        out_name=out_name,
        gis=gis
    )
    
    return Path(out_report)

# %%
study_areas = Geometry({"rings":[[[-117.26,32.81],[-117.40,32.92],[-117.12,32.80],[-117.26,32.81]]], "spatialReference":{"wkid":4326}})

load_dotenv(find_dotenv())

dir_prj = Path.cwd().parent
dir_data = dir_prj/'data'
dir_reports = dir_prj/'reports'
assert dir_reports.exists()

url, user, pswd = [os.getenv(itm) for itm in ['AGOL_URL', 'AGOL_USERNAME', 'AGOL_PASSWORD']]
assert all([url, user, pswd])

gis = GIS(url, username=user, password=pswd)

gis
# Out:
# GIS @ https://baqa.mapsqa.arcgis.com version:9.3

# %%
out_report = custom_create_report(study_areas, gis, 'tapestry-profile', dir_reports/'tapestry-test.pdf')

out_report
# Out:
# PosixPath('/Users/joel5174/projects/python-generate-infographic/reports/tapestry-test.pdf')

# %%
report_id = 'b3102bdb4cec4795987f64e385066684'
report = {"itemid": report_id}

# %%
out_report = custom_create_report(study_areas, gis, report_id, dir_reports/'custom-infographic-test.pdf', 'pdf')

out_report
# Out:
# PosixPath('/Users/joel5174/projects/python-generate-infographic/reports/custom-infographic-test.pdf')
